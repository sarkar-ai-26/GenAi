# %%
from torchgen.api.types import bfloat16T
# !pip install transformers

# %%
# !pip install python-dotenv

# %%
#to load the env paramters from .env file, secret keys
from dotenv import load_dotenv

# %%
#AutoTokenizer -> to tokenize automatically
from transformers import AutoTokenizer, AutoModelForSequenceClassification

# %%
#Loading the .env file secret keys
load_dotenv()
# Out:
# True

# %%
#creating object that can return the tokens of the inputs
tokenizer = AutoTokenizer.from_pretrained('google/gemma-2-2b-it')

# %%
tokenizer("Hello, this sentence to find tokens")
# Out:
# {'input_ids': [2, 4521, 235269, 736, 13060, 577, 1717, 24571], 'attention_mask': [1, 1, 1, 1, 1, 1, 1, 1]}

# %%
# !pip install -U langchain-google-genai

# %%
from langchain_google_genai import GoogleGenerativeAIEmbeddings

# %%
gemeni_embeding = GoogleGenerativeAIEmbeddings(model='gemini-embedding-2',output_dimensionality=150)

# %%
query = "Hello, embedding the text"
vectordata = gemeni_embeding.embed_query(query)
print(f"Embedded data: {vectordata}")
print(f"Length for query vector data : {len(vectordata)}")

# %% [markdown]
# ### Generate next work prediction

# %%
 # !pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu126

# %%
#to check cuda and import pytorch (torch)
import torch
torch.cuda.is_available()
# Out:
# True

# %%
from transformers import AutoModelForCausalLM

# %%
model = AutoModelForCausalLM.from_pretrained(
    'google/gemma-2-2b-it',
    torch_dtype=torch.float16,
    device_map="auto",
    low_cpu_mem_usage=True, #to use cpu less, gpu more
    offload_buffers=True, #to offload the ,model buffers in gpu
    local_files_only=True #to use already downloaded local model
)

# %%
tokens = tokenizer('Write python print syntax',return_tensors = 'pt')
tokens = {key: value.to('cuda') for key, value in tokens.items()}

# %%
#this will generate different predictions
output = model(input_ids=tokens["input_ids"])
print(output)
# Out:
# CausalLMOutputWithPast(loss=None, logits=tensor([[[-16.3438,  -5.8477,  -0.6597,  ..., -11.1797, -11.1328, -16.3281],
#          [-14.4844,  -9.8359, -21.2031,  ..., -10.5547,  -8.6328, -13.7656],
#          [-15.3516,  -3.3359,  -2.6523,  ...,  -9.3906,  -6.6367, -14.8281],
#          [-13.2656,  -3.9375,  -7.2031,  ...,  -7.5508,  -5.7344, -12.8672],
#          [-11.9453,   2.6777,  -2.1523,  ...,  -2.5273,  -1.7520, -11.3750]]],
#        device='cuda:0', dtype=torch.float16, grad_fn=<MulBackward0>), past_key_values=DynamicCache(layers=[DynamicSlidingWindowLayer, DynamicLayer, DynamicSlidingWindowLayer, DynamicLayer, DynamicSlidingWindowLayer, DynamicLayer, DynamicSlidingWindowLayer, DynamicLayer, DynamicSlidingWindowLayer, DynamicLayer, DynamicSlidingWindowLayer, DynamicLayer, DynamicSlidingWindowLayer, DynamicLayer, DynamicSlidingWindowLayer, DynamicLayer, DynamicSlidingWindowLayer, DynamicLayer, DynamicSlidingWindowLayer, DynamicLayer, DynamicSlidingWindowLayer, DynamicLayer, DynamicSlidingWindowLayer, DynamicLayer, DynamicSlidingWindowLayer, DynamicLayer]), hidden_states=None, attentions=None)

# %%
#to generate the real output token ids
gen_output=model.generate(tokens['input_ids'],attention_mask=tokens['attention_mask'],max_new_tokens=100)
print(gen_output)

# %%
#to generate the token ids in real text format
tokenizer.batch_decode(gen_output)
# Out:
# ['<bos>Write python print syntax\n\n```python\nprint("Hello, world!")\n```\n\n**Explanation:**\n\n* **`print()`** is a built-in function in Python that displays output to the console.\n* **`"Hello, world!"`** is a string literal, enclosed in double quotes. This is the text you want to print.\n\n**How it works:**\n\n1. The `print()` function takes the string as an argument.\n2. The `print()` function then displays the string']
