# %%
from dotenv import load_dotenv
load_dotenv()

# %%
from langchain_ollama import OllamaEmbeddings

# %%
ollamaEmb = OllamaEmbeddings(model="embeddinggemma")

# %%
# ollamaEmb = OllamaEmbeddings(model="llama3.1:8b")

# %%
docsList = ['Hello this is first GenAI embedding sentence', 'Here i am learning the concept of embedding',
            'And i am also learning the practical usage with gemeni-embedding-2 model']
query = 'What user is learning here?'

# %%
len(ollamaEmb.embed_query(query))
# Out:
# 768

# %%
len(ollamaEmb.embed_documents(docsList))
# Out:
# 3
