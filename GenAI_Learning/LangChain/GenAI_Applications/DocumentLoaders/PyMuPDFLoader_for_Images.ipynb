# %%
from langchain_community.document_loaders import PyMuPDFLoader

# %%
load = PyMuPDFLoader(r'/GenAI_Learning/LangChain/GenAI_Applications/DataBase/GermanyInstitutionsRules.pdf')

# %%
doc = PyMuPDFLoader.load(load)

# %%
doc[0].page_content
# Out:
# 'Studying in Germany\nA Practical Guide for\nInternational Students\n7th Edition'
