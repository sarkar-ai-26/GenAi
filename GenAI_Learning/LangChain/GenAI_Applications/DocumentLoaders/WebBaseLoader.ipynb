# %%
from langchain_community.document_loaders import WebBaseLoader, SeleniumURLLoader

# %%
loader = WebBaseLoader(r'https://www.amazon.in/Samsung-Storage-Powerful-Snapdragon-Processor/dp/B0H4L5T84X/?_encoding=UTF8&pd_rd_w=1Zzzs&content-id=amzn1.sym.c7856867-7399-4487-8ea1-2895e0decba2%3Aamzn1.symc.96b8365e-3b12-433f-a173-648d41788658&pf_rd_p=c7856867-7399-4487-8ea1-2895e0decba2&pf_rd_r=2NT63VH24TVAZK7AACFE&pd_rd_wg=DTvRu&pd_rd_r=9472132e-e518-471c-96a3-5e09c0647a8b&ref_=pd_hp_d_btf_ci_mcx_mr_hp_atf_m')

# %%
loaderX = SeleniumURLLoader('https://www.make-it-in-germany.com/en/visa-residence/skilled-immigration-act')

# %%
# !pip install beautifulsoup

# %%
doc = WebBaseLoader.load(loader)

# %%
docs = SeleniumURLLoader.load(loaderX)

# %%
doc[0].metadata
# Out:
# {'source': 'https://www.amazon.in/Samsung-Storage-Powerful-Snapdragon-Processor/dp/B0H4L5T84X/?_encoding=UTF8&pd_rd_w=1Zzzs&content-id=amzn1.sym.c7856867-7399-4487-8ea1-2895e0decba2%3Aamzn1.symc.96b8365e-3b12-433f-a173-648d41788658&pf_rd_p=c7856867-7399-4487-8ea1-2895e0decba2&pf_rd_r=2NT63VH24TVAZK7AACFE&pd_rd_wg=DTvRu&pd_rd_r=9472132e-e518-471c-96a3-5e09c0647a8b&ref_=pd_hp_d_btf_ci_mcx_mr_hp_atf_m',
#  'title': 'Samsung Galaxy M47 5G (Rogue Red, 6GB RAM, 128GB Storage)| Powerful Snapdragon Processor| Fast LPDDR5x RAM,UFS 3.1 Storage| Gorilla Glass Victus+| IP64| Super AMOLED Display| 50MP OIS| AI| Gemini Live : Amazon.in: Electronics',
#  'description': 'Samsung Galaxy M47 5G (Rogue Red, 6GB RAM, 128GB Storage)| Powerful Snapdragon Processor| Fast LPDDR5x RAM,UFS 3.1 Storage| Gorilla Glass Victus+| IP64| Super AMOLED Display| 50MP OIS| AI| Gemini Live : Amazon.in: Electronics',
#  'language': 'en-in'}

# %%
len(doc)
# Out:
# 1

# %%
doc[0].page_content
# Out:
# "\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSamsung Galaxy M47 5G (Rogue Red, 6GB RAM, 128GB Storage)| Powerful Snapdragon Processor| Fast LPDDR5x RAM,UFS 3.1 Storage| Gorilla Glass Victus+| IP64| Super AMOLED Display| 50MP OIS| AI| Gemini Live : Amazon.in: Electronics\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSkip to\n\n\n\n        Main content\n      \n\n\n\n        About this item\n      \n\n\n\n        About this item\n      \n\n\n\n        About this item\n      \n\n\n\n        Buying options\n      \n\n\n\n        Compare with similar items\n      \n\n\n\n        Videos\n      \n\n\n\n        Reviews\n      \n\n\n\n\n      Keyboard shortcuts\n  \n\n\n\n\nSearch\n\nalt\n+\n/\n\n\n\n\n\n\n\nCart\n\nshift\n+\nalt\n+\nC\n\n\n\n\n\n\n\nHome\n\nshift\n+\nalt\n+\nH\n\n\n\n\n\n\n\nOrders\n\nshift\n+\nalt\n+\nO\n\n\n\n\n\n\n\nAdd to cart\n\nshift\n+\nalt\n+\nK\n\n\n\n\n\n\n\nProduct summary\n\nshift\n+\nalt\n+\nD\n\n\n\n\n\n\n\nShow/Hide shortcuts\n\nshift\n+\nalt\n+\nZ\n\n\n\n\n\n\n\n\n\n\nTo move between items, use your keyboard's up or down arrows.\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n.in\n\n\n\n\n\n\n\n\n\n                   Delivering to Ranchi 834001\n                \n\n                   Update location\n                \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nElectronics\n\n\nSelect the department you want to search in\n\nAll Categories\nAlexa Skills\nAmazon Devices\nAmazon Fashion\nAmazon Fresh\nAmazon Pharmacy\nAppliances\nApps & Games\nAudible Audiobooks\nBaby\nBeauty\nBooks\nCar & Motorbike\nClothing & Accessories\nCollectibles\nComputers & Accessories\nDeals\nElectronics\nFurniture\nGarden & Outdoors\nGift Cards\nGrocery & Gourmet Foods\nHealth & Personal Care\nHome & Kitchen\nIndustrial & Scientific\nJewellery\nKindle Store\nLuggage & Bags\nLuxury Beauty\nMovies & TV Shows\nMP3 Music\nMusic\nMusical Instruments\nOffice Products\nPet Supplies\nPrime Video\nShoes & Handbags\nSoftware\nSports, Fitness & Outdoors\nSubscribe & Save\nTools & Home Improvement\nToys & Games\nUnder ₹500\nVideo Games\nWatches\n\n\n\n\n\n\nSearch Amazon.in\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nEN\n\n\n\n\n\n\n\nHello, sign in\nAccount & Lists\n  \n\n\n\n\nReturns\n& Orders\n\n\n\n0\n\n\n\n\n\n\n        Cart\n        \n\n\n\n\n\n\n\n\n\n\n\n\n\nAll\n\n\n\n\n\n\n\n\n\n\n\n\n\nFresh\n\n\n\n\nMX Player\n\n\n\n\nSell\n\n\n\n\nBestsellers\n\n\n\n\nToday's Deals\n\n\n\n\nMobiles\n\n\n\n\nNew Releases\n\n\n\n\nPrime\n\n\n\n\n\n\nAmazon Pay\n\n\n\n\n Electronics \n\n\n\n\nCustomer Service\n\n\n\n\nHome & Kitchen\n\n\n\n\nFashion\n\n\n\n\nComputers\n\n\n\n\nToys & Games\n\n\n\n\nCar & Motorbike\n\n\n\n\nPet Supplies\n\n\n\n\nHome Improvement\n\n\n\n\nGift Cards\n\n\n\n\nSports, Fitness & Outdoors\n\n\n\n\nBeauty & Personal Care\n\n\n\n\nVideo Games\n\n\n\n\nBaby\n\n\n\n\nCustom Products\n\n\n\n\nGrocery & Gourmet Foods\n\n\n\n\nHealth, Household & Personal Care\n\n\n\n\nAmazonBasics\n\n\n\n\nAudible\n\n\n\n\nSubscribe & Save\n\n\n\n\nKindle eBooks\n\n\n\n\nBooks\n\n\n\n\nFlights\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n        Mobiles & Accessories\n        \n      \n\n\n\n\n\n\n\n\n        Laptops & Accessories\n        \n      \n\n\n\n\n\n\n\n\n        TV & Home Entertainment\n        \n      \n\n\n\n\n\n\n\n\n        Audio\n        \n      \n\n\n\n\n\n\n\n\n        Cameras\n        \n      \n\n\n\n\n\n\n\n\n        Computer Peripherals\n        \n      \n\n\n\n\n\n\n\n\n        Smart Technology\n        \n      \n\n\n\n\n\n\n\n\n        Musical Instruments\n        \n      \n\n\n\n\n\n\n\n\n        Office & Stationery\n        \n      \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n  \n \n\n\n\n\n\nCustomers who viewed this item also viewedSamsung Galaxy A56 5G (Awesome Midnight Blue, 8GB, 256G ...

# %%
doc
# Out:
# [Document(metadata={'source': 'https://www.amazon.in/', 'title': 'Amazon.in', 'language': 'en-us'}, page_content='\n\n\n\n\n\n\n\n\nAmazon.in\n\n\n\n\n\n\n\n\n\n\n\n\nClick the button below to continue shopping\n\n\n\n\n\n\n\n\n\n\n\n\nContinue shopping\n\n\n\n\n\n\n\n\n\n\n\nConditions of Use & Sale\n\n\n\n\nPrivacy Notice\n\n\n          © 1996-2025, Amazon.com, Inc. or its affiliates\n        \n\n\n')]
