# %%
from langchain_community.document_loaders import DirectoryLoader,PyPDFLoader
# Out:
# C:\Users\yashr\AppData\Local\Temp\ipykernel_24224\2214615433.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import DirectoryLoader,PyPDFLoader

# %%
loader = DirectoryLoader(path=r'/GenAI_Learning/LangChain/GenAI_Applications/DataBase', glob='*.pdf', loader_cls=PyPDFLoader)

# %%
docs = DirectoryLoader.load(loader)

# %%
docs = DirectoryLoader.lazy_load(loader)

# %%
len(docs)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 len(docs)
#
# TypeError: object of type 'generator' has no len()

# %%
docs[2].page_content
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 docs[2].page_content
#
# TypeError: 'generator' object is not subscriptable
