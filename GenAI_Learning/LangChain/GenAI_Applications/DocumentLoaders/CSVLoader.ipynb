# %%
from langchain_community.document_loaders import CSVLoader
# Out:
# C:\Users\yashr\AppData\Local\Temp\ipykernel_26592\1791378509.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import CSVLoader

# %%
loader = CSVLoader(r'C:\YashAssets\PythonProjects\GenAi\GenAI_Learning\LangChain\GenAI_Applications\DataBase\StudentDepressionDataset.csv')

# %%
docs = CSVLoader.load(loader)

# %%
docs[0].metadata
# Out:
# {'source': 'C:\\YashAssets\\PythonProjects\\GenAi\\GenAI_Learning\\LangChain\\GenAI_Applications\\DataBase\\StudentDepressionDataset.csv',
#  'row': 0}

# %%
docs[0].page_content
# Out:
# 'id: 2\nGender: Male\nAge: 33.0\nCity: Visakhapatnam\nProfession: Student\nAcademic Pressure: 5.0\nWork Pressure: 0.0\nCGPA: 8.97\nStudy Satisfaction: 2.0\nJob Satisfaction: 0.0\nSleep Duration: 5-6 hours\nDietary Habits: Healthy\nDegree: B.Pharm\nHave you ever had suicidal thoughts ?: Yes\nWork/Study Hours: 3.0\nFinancial Stress: 1.0\nFamily History of Mental Illness: No\nDepression: 1'

# %%
len(docs)
# Out:
# 27901

# %%
docs
# Out:
# [Document(metadata={'source': 'C:\\YashAssets\\PythonProjects\\GenAi\\GenAI_Learning\\LangChain\\GenAI_Applications\\DataBase\\StudentDepressionDataset.csv', 'row': 0}, page_content='id: 2\nGender: Male\nAge: 33.0\nCity: Visakhapatnam\nProfession: Student\nAcademic Pressure: 5.0\nWork Pressure: 0.0\nCGPA: 8.97\nStudy Satisfaction: 2.0\nJob Satisfaction: 0.0\nSleep Duration: 5-6 hours\nDietary Habits: Healthy\nDegree: B.Pharm\nHave you ever had suicidal thoughts ?: Yes\nWork/Study Hours: 3.0\nFinancial Stress: 1.0\nFamily History of Mental Illness: No\nDepression: 1'),
# ...

# %%
print(docs[0].page_content)
# Out:
# id: 2
# Gender: Male
# Age: 33.0
# City: Visakhapatnam
# Profession: Student
# Academic Pressure: 5.0
# Work Pressure: 0.0
# CGPA: 8.97
# Study Satisfaction: 2.0
# Job Satisfaction: 0.0
# Sleep Duration: 5-6 hours
# Dietary Habits: Healthy
# Degree: B.Pharm
# Have you ever had suicidal thoughts ?: Yes
# Work/Study Hours: 3.0
# Financial Stress: 1.0
# Family History of Mental Illness: No
# Depression: 1
