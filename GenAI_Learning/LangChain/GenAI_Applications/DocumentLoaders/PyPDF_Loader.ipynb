# %%
from langchain_community.document_loaders import PyPDFLoader

# %%
pdf_load = PyPDFLoader(r'/GenAI_Learning/LangChain/GenAI_Applications/DataBase/GermanJobs_international_Rules.pdf')

# %%
loading_doc = PyPDFLoader.load(pdf_load)

# %%
loading_doc[0].page_content
# Out:
# 'Job  \nregulations for \ninternational \nstudents  \nin Germany \nInformation for \nstudents\nEnglish version'

# %%
loading_doc[0].metadata
# Out:
# {'producer': 'Adobe PDF Library 17.0',
#  'creator': 'Adobe InDesign 18.5 (Macintosh)',
#  'creationdate': '2023-12-20T14:30:32+01:00',
#  'moddate': '2024-01-16T14:47:55+01:00',
#  'title': 'Job regulations for international students in Germany',
#  'trapped': '/False',
#  'source': 'C:\\YashAssets\\PythonProjects\\GenAi\\GenAI_Learning\\LangChain\\GenAI_Applications\\DataBase\\Jobs_international_Rules.pdf',
#  'total_pages': 6,
#  'page': 0,
#  'page_label': '1'}

# %%
len(loading_doc)
# Out:
# 6
