# %% [markdown]
# # LangChain
#
# > Roles That comes under : (AI Developer, LLM Engineer. GenAi Engineer, RAG Developer)
#
# - We can create LLM applications using already available LLMs.
#
# ### Problem with LLM to use directly?
# - LLM model don't remember context beyond the prompt.
# - It doesn't have the context for the next follow-up queries.
# - They can not use directly external data sources like, apis, databases, etc.
# - LLM models cant perform actions like searching the web, running code., or queries SQL by themselves.
#
# ### What is LangChain?
#
# - It's an opensource framework that helps in building LLM based application.
# - It provides modular components or end to tools like data collecting data, data injetion, connecting data and more, that helps developer build complex AI application. Such as ChatBots, Workflow Agents, Query bots, RAG application, Autonomous AI agents, AI knowledge assistant.
#
# ### Features of Langchain
#
# - It supports all major LLMs like OpenAi GPT, Google Gemeni, Gemma, Hugging face models, LLAMA, Mistral etc.
# - This framework helps us in connecting all these LLMs with our own data.
# - It simplifies development LLM based application as it is having major tools as
#     - chains : it chains together all tools, and that why complex application requireing multiple app together can be easily build.
#         ![image.png](attachment:d2995e9c-69fa-4475-8c63-d2784671b804.png)
# - It is opensource.
# - It can manage complex workflows, where llms interact with databases, 3rd party softwares, mcp servers and more.
# - Its a bridge between LLMs and real world data and application, and to chain all together.
#
# ### Why LangChain and benefits?
#
# - Memory : That keeps track of the conversation and context.
# - Data-connector : It helps is connecting any kind of database like, AWS, GCP, Azure, SQL, APIs, Google Drive, Localdrive.
# - Data Loaders : It helps in loading different kind of data.
# - Tools & Agents : Let Llms takes action on their own., Browsing capability, python code execution, check 3rd party softwares and grab functionalities.
# - Chains : It helps in structuring these workflows.
# - Model Agnostic Development -> We can shift from one model to another, or databases, or apis.
# - It Provides complete Ai Ecosystem.
# - Langsmith : To deploy the application or convert the application in API so it can be used from out source.

# %% [markdown]
# ### Installation of LangChain
#
# Creating Python vertual env
#
# >> conda -p venv python==3.14 -y
# >> pip install -U langchain
#
# Installing the OpenAI integration
# >> pip install -U langchain-openai
#
# Installing the Anthropic integration
# >> pip install -U langchain-anthropic
#
# We need to minitor the performance of our model, we need langchain and langsmith api key

# %% [markdown]
# ### Langchain Important Components
#
# - Models
# - Prompts
# - Chains
# - Memory
# - Indexes
# - Agents

# %% [markdown]
# ## Prompting Frameworks
#
# > **Standard Structure : Role -> Goal -> Context -> Example -> Output Structure**
#
# - Shot prompting : In this we need to provide example to model to how to generate response data.
#     - Zero shot prompting : No previous data provide, just question.
#     - One shot prompting : In this we need to give one example for response.
#     - Few shot prompting : In this we need to provide more than 1 examples to create the context of the prompt.
# - Chain of thoughts : This helps models to explain its answers in a step by step format. Ex, Lets think step by step, behind the solution.
# - Ask before answer technique : Model will ask user for the options or method to go forward with the response.
# - Fill in the blanks prompting : User will ask model to provide bullet points questions? and then user will provide the answer with the points mentioned, and then model will do the next response generation.
# - Reverse Prompting : Reverse engineering, such that user will have the response or content already, and then user can ask query to generate the prompt used.
# - RGC Prompting : **Role -> Goal -> Context** -> Result -> Constraint

# %% [markdown]
# ## Chains in LangChain
#
# - Pipeline b/w multiple LLms, vector db, document loader, and etc, To bind these things together, to chain it together, to create a pipeline, we need chain.
#     - Parallel chains
#     - Conditional chains
#
# ## Indexes (RAG) : It helps with connecting application to an external kb.
#
#     - Doc loader
#     - Text Splitter
#     - vector store
#     - Retriever
#
# Ex. PDF --> Upload to any storage server (ex AWS S3)--> Doc Loader --> PDF ---> Text Splitter ( Page by Page ) --> Vector Embedding conversion --> Store in Vector database (ex. chroma db)
#
# Now user can ask query --> Retriever --> Embedding of query -->  Semantic search in vector database --> Passed to system query --> Best possible embedding will passed to LLM Model --> It can create a summary or brief to deliver to user.
#
# ![image.png](attachment:3af6d52c-3322-4b50-9066-6e986b8c1a8c.png)
# ![image.png](attachment:ffbc5228-a80b-4e59-9ff9-f3d1e1c59ae2.png)
# ![image.png](attachment:db4c0471-da67-457a-8735-8f965c7b1cab.png)
# ![image.png](attachment:673fab2f-0feb-4c3d-9c7c-a032b2e521d9.png)

# %% [markdown]
# ## Memory
#
# ![image.png](attachment:b0796d7f-c0b2-4074-b16d-dbc2a1fa200d.png)
# ![image.png](attachment:7159e6cd-1120-4124-b627-57484640725d.png)
#
# - Conversation Buffer memory :  The conversation buffer memory is getting stored and passed in next input to keep the last context.
# - Conversation Buffer Window Memory : It can have buffer memory context for last n number of conversation.
# - Summariser based memory : Summary for last n number for conversation can be passed to next conversation. It periodically summarises the older chat segments to keep a context memory footprint.
# - Custom Memory : Specified info in the memory.

# %% [markdown]
# ## Agents
#
# - For building Ai Agents , we can use agent component of langchain.
# - Reasoning capabilities - Chain of thought prompting
# - It has many tools

# %% [markdown]
# ## Document Loaders
#
# - As LLMs does not have access to the personal or some required data, document loaders will help in solve this issue.
# - It is a utility to bring external data into the llm application. From different data sources, file formats such as csv, excel, text, json, xml, website, google drive, pdf, word , db file, etc.
# - It converts the data in multiple formats into a standardized format such as document object that is understandable by LLms
# - LLMs need structures , clean and chunked data to work with.
# - Document object:
#     - Page Content : Actual text
#     - Meta data : Info of the file, page number, source url, source, timestamp
# - It helps in indexing, retrieval, qa workflows, rag.
#
# > Major document loaders:
# - Text loader
# - PyPdf loader
# - WebBase loader
# - csv loader
# - Excell loader
# - S3Directory loader
# - S3FileLoader
# - AzureAiDataLoader
# - etc.

# %% [markdown]
# ### Text Loaders
#
# - It is being used to gather data from .txt format.
# - > TextLoader - > Document object
# - Usecase :
#     - Chat logs
#     - Scraped text
#
# > from langchain_community.document_loaders import TextLoader
#
# > loader = TextLoader(r'C:\YashAssets\PythonProjects\GenAi\GenAI_Learning\LangChain\GenAI_Applications\DataBase\GermanLaws.txt',encoding='utf-8')
#
# > docs = loader.load()
# > print(docs)
#
# > docs[0].metadata
#
# > docs[0].page_content

# %% [markdown]
# ### PyPDF Loader
#
# > pip install pypdf
#
# - It helps in reading pdf file.
# - Each page in pdf, treats as separate document.
# - It will only help in text content in pdf file.
#
# > from langchain_community.document_loaders import PyPDFLoader
#
# > pdf_load = PyPDFLoader(r'C:\YashAssets\PythonProjects\GenAi\GenAI_Learning\LangChain\GenAI_Applications\DataBase\Jobs_international_Rules.pdf')
#
# > loading_doc = PyPDFLoader.load(pdf_load)
# > loading_doc[0].page_content
#
# ### PDFPlumberloader
#
# >To work with tables or columns consisting PDF
#
# > pip install pdfplumber
#
# > from langchain_community.document_loaders import PDFPlumberLoader
#
# > load = PDFPlumberLoader(r'C:\YashAssets\PythonProjects\GenAi\GenAI_Learning\LangChain\GenAI_Applications\DataBase\GermanVisaChecklist.pdf')
#
# > doc = PDFPlumberLoader.load(load)
#
# > doc[0].page_content
#
# > doc[0].metadata
#
# ### PyMuPDFLoader
#
# > It used for Pdfs with basic images layout, image data.
# > Note : Not scanned images
#
# > from langchain_community.document_loaders import PyMuPDFLoader
#
# > load = PyMuPDFLoader(r'C:\YashAssets\PythonProjects\GenAi\GenAI_Learning\LangChain\GenAI_Applications\DataBase\GermanyInstitutionsRules.pdf')
#
# > doc = PyMuPDFLoader.load(load)
#
# > doc[0].page_content
#
# ### UnstructuredPDFLoader or AmazonTextractPDFLoader
#
# > PDf with complete scanned images

# %% [markdown]
# ### DirectoryLoader
#
# - It is document loader that lets us load multiple documents from a directory and files.
# - It takes files with pattern extension.
#
# > Global patterns
# - "**/*.txt" -> All .txt files in subfolder
# - "*.pdf" -> All .odf files in subfolder.
# - "data/*csv" -> to load all .csv file
# - "*/*" -> all files of anytype
# - Parameter : glob, pattern, loader-cls -> exact or actual doc loader to used ot load those files
#
# Notes:
# - Indexing on multiple file.
# - pdf1 (10 pages) -> doc[0,9]

# %% [markdown]
# # Problem with load -> it will load all files content in the memory, and it will take lot of time

# %% [markdown]
# > load() -> It is eager loading, as it loades everything at once and return a list of document object, That means, if we have very less document then it is okay, but when the data is huge, files are huge, then its very time and memory consuming module.
#
# > lazy_load() -> It load with demand basis. And return a generator document object. So all documents are not loaded and once, it loads as per requirement. It is used for large documents, or lot of files.
#
# > In LangChain, lazy loading (.lazy_load()) is a memory-efficient technique used in Document Loaders to process and stream large datasets. .
#
# > Instead of loading all documents into memory at once as a list (which causes out-of-memory errors), .lazy_load() yields documents one by one using a Python generator.
#
# > Why use .lazy_load()?
# - Low Memory Footprint: Ideal for handling thousands of PDFs, large CSVs, or massive database dumps.
# - Streaming & Chinking: You can chunk, embed, or send documents to a vector store as soon as a single document is yielded, releasing memory before the next one is processed.How to use itMost modern LangChain document loaders support both .load() (eager) and .lazy_load()

# %% [markdown]
# ## WebBaseLoader
#
# - It used to gather the data or content from webpage from weburl.
# - It used Beautifulsoup library under the hood, to parse html and extract visible data.
# - It can be used for blogs, news article, public website information.
# - The HTMl should be heavy text based.
# - It loads static content from the html. Not dynamic buttons directed subpages.
# - It can take multiple web urls in list format, and also can perform indexing slicing.
# > from langchain_community.document_loaders import WebBaseLoader, SeleniumURLLoader
#
# ## SeleniumURLLoader
#
# - For HTML and javascript heavy based webpages.
#
# ## CSVLoader
#
# - As name suggests, it used to load the csv file content.
# - Total documents = Total rows
#
# > from langchain_community.document_loaders import CSVLoader

# %% [markdown]
# ## Text - Splitters
#
# - It devides large documents into smaller chunks of text.
# - These chunk can be used for embedding, semantic search, and for RAG.
# - It also helps in downstream tasks
#     - Embedding -> short chunks yield more accurate vectors.
#     - Semantic search
# - To get rid of hallucination.
# - To optimize computation resouces, and make more memory efficient, and allow more parallel processing.
# - Types:
#     - Length Based
#     - Text Structure Based
#     - Document Structure Based
#     - Semantic Meaning based
#
# ![image.png](attachment:602d02e8-e7ab-48cb-8faf-d6b758a1afba.png)

# %% [markdown]
# ## Length Based Text Splitter
#
# - It is the fastest text splitting technique and easiest.
# - Here it splits the data where we already decide that how many characters or tokens we need to have in every chunks.
# - **Not Recomeneded** (chunks can be incomplete in the starts and ends of chunks).
# - It can not capture linguistic meaning and semantic meaning.
#
# > from langchain_text_splitters import CharacterTextSplitter
#
# > textSplit = CharacterTextSplitter(chunk_size=100,chunk_overlap=20,separator='')
#
# > chunks = textSplit.split_text(''' '''')
#
# >chunks[0]
#
# - Parameters:
# - chunk_size : chunk size in each chunk
# - chunk_overlap : Overlap b/w chunks to maintains the chunks. It can be 10% of chunk size.
# - separators : Any Separators between the text data.
#
# ## Text Structure Based Text Splitting
#
# - Structure Of Text
#     - Para
#         - Sentence
#             - Word
#                 - Character
#
# - We can break via paragraph, Sentence, word, character basis chunk by chunk.
# - This is the **most used technique** because this doesn't break words or sentences in mid way.
# - This insured chunks are semantically meaning-full, and dont break important context.
#
# >Library : RecursiveCharacterTextSplitter
#
# - How to decide how to break?
#     - chunk_size : it decided how to break, via para or sentence, word.
#
# > from langchain_text_splitters import RecursiveCharacterTextSplitter
#
# > loader = RecursiveCharacterTextSplitter(chunk_size=200, chunk_overlap=20)
#
# > chunks = loader.split_text(''' ''')
#
# > print(chunks[0])

# %% [markdown]
# ## Document Structure Based Splitter
#
# - Splitting will happens based on Document structure like for coding etc.
# >from langchain_text_splitters import RecursiveCharacterTextSplitter ,Language
#
# >Splitter = RecursiveCharacterTextSplitter.from_language(chunk_size=100,chunk_overlap=0,language = Language.PYTHON)
#
# > RecursiveCharacterTextSplitter -> Parameter (language=HTMl/Python etc. )
#
# >chunks=Splitter.split_text('''''')
#
# - We have specify the language in the parameter.
#
# ## Semantic Meaning Based Splitter
#
# - Semantic text splitting means breaking text into chunks based on meaning and context, and not just by character count, token or structure.
# - It uses splitters that splits by creating embeddings of a sentence and then those of similar embeddings and then it group together.
# - For overall text it breakdown first by structure, then it perform embedding simmilarity on the break chunks and provide the result.
#
# - ![image.png](attachment:dee6de37-e70a-4607-92a8-ebdfe4a23cbd.png)

# %% [markdown]
# ## Embedding Models
#
# - To convert the textual data into numerical format, in tokens.
# - Vector store is being used to store these data in number format.
# - Embedding models are used to convert the textual to embeddings.
# - Ex Models - > LLM, chat models, embedding models.
# - Each vector capture the semantic meaning of the text.
# - In Langchain , embedding are used for search, retrieval, clustering, classification and recommendation.
# - It is a way turning language into maths, so that computer can compare meaning.
# - Query(text) --> Convert to embedding --> LLM --> Search in Vector store
# - Find similar text (semantic search)
# - Retrieve relevant chunks from large data.
# - It also detects clusters or duplicates.
# - There are general and domain specific embedding models and multi model embeddings as well.
#
#
# ![image.png](attachment:26611dc5-63b3-4533-a7e9-c5936f91cf29.png)
# ![image.png](attachment:6e090ff2-942a-461a-b43f-3b1bf5944f68.png)

# %% [markdown]
# ## Ollama Introduction
#
# - Ollama is a framework, that makes it easy to use large language models runs locally in the system.
# - It supports open source popular models. Like, llama, gemma, mistral, deepseek, phi etc.
# - We can have text generation model, along with this it also has embedding models.
# - Ollama runs entirely on our local system, NO API Cost, full secure, can work offline.
# - We can finetune the models.

# %% [markdown]
# ## Vector Stores
#
# - It Stores embeddings along with text or documents (meta data).
# - It store it locally to allow fast similarity search without breaking the wallet.
# - It is like a search engine for semantic meaning.
# - Vector - > Storing vector embedding -> Retrieving data.
# - ![image.png](attachment:73800e2e-3371-4006-bae9-c8e55ca878e4.png)
# - ![image.png](attachment:30663308-f9c5-4062-bf4d-52c4c7a827ad.png)
# - Indexing -> It provides a data structure or method that enables for similarity searches on the high dimensional vectors.
# - Crud Operation can be done.
#
# ### Vector data Stores
# 1. FAISS -> It get stored in RAM, when application closed, the data will also be vanished. (Not Recommended)
# 2. Chromadb -> It stores in disk, or hard-drive. (Recommended)
#
# ## Vector Stores vs Vector Database
#
# - Vector Store
#     -  Typically refers to lightweight library that focus on storing vectors and performing similarity search. It also used for retrieval of embeddings.
#     -   May not include traditional database features line transaction, rich query language or role bases access control.
#     -  Ideal for prototypes, smaller scale applications. Ex. FAISS
#
# - Vector Database
#     - A fully fledged database designed to store query vectors.
#     - Offers addition database like features.
#         1. Distributed architecture.
#         2. Durability and persistence.
#         3. Metadata handling ( Schemas, filters )
#       4. Authentication and security.
#
# ![image.png](attachment:5e8dbe34-3f33-4b08-b575-5fd2474cee1a.png)
#
# - In langchain, for different vector stores and vector database, interface will be similar.
# - Modules:
#     - from_documents()
#     - from_text()
#     - add_documents(doc) -> TO insert
#     - add_text(query) -> TO insert
#     - similarity_search(query,k=n)
#     - get(include=['documents','embeddings','metadata'])
#
# ### ChromaDB
#
# - It is lightweight open source vector database for local development and small to medium scale production needs.
# - It comes in between vector store and vector database.
#
# > Chroma DB tenancy and Db Hierarchy
# ![image.png](attachment:cf2ac586-b5f9-4218-813c-346cc9d31133.png)
