# %% [markdown]
# ![image.png](attachment:0017c40d-d9ba-4455-bbd5-5131d043318f.png)

# %% [markdown]
# ![image.png](attachment:ae9aa1ef-e7fa-4994-946d-b7149c7ac66a.png)

# %%
from langchain_community.document_loaders import TextLoader

loader = TextLoader(r'C:\YashAssets\PythonProjects\GenAi\GenAI_Learning\LangChain\GenAI_Applications\DataBase\GermanLaws.txt',encoding='utf-8')
docs=TextLoader.load(loader)
print(len(docs))
print(docs[0].page_content)
print(docs[0].metadata)
# Out:
# 1
# Job
# regulations for
# international
# students
# in Germany
# Information for
# students
# English version
# Working in Germany
# A part-time job provides you with the opportunity to gain experience,
# get to know Germany, make contacts and supplement the financing
# of your studies. It is very difficult to finance your studies and life in
# Germany with a part-time job alone, and if you have a part-time job
# that takes up a lot of time, your academic performance will suffer.
# This may prolong your studies and, in the worst case, jeopardise
# your residence title.
# IMPORTANT For many student jobs, knowledge of German
# is necessary.
# Students from the EU/EEA/Switzerland
# If you are a student with citizenship in a member state of the European Union (EU), the European Economic Area (EEA) or Switzerland
# you may take up any type of work in Germany under the same
# conditions as German students.
# IMPORTANT If you are a student with citizenship in the
# ...

# %% [markdown]
# ![image.png](attachment:b48d1c16-5e85-404a-b79d-2603bb1ebf2b.png)

# %%
from langchain_community.document_loaders import CSVLoader

loader_ =CSVLoader(r'C:\YashAssets\PythonProjects\GenAi\GenAI_Learning\LangChain\GenAI_Applications\DataBase\StudentDepressionDataset.csv')
docs = CSVLoader.load(loader_)
print(len(docs))

print(docs[2].page_content)
# Out:
# 27901
# id: 26
# Gender: Male
# Age: 31.0
# City: Srinagar
# Profession: Student
# Academic Pressure: 3.0
# Work Pressure: 0.0
# CGPA: 7.03
# Study Satisfaction: 5.0
# Job Satisfaction: 0.0
# Sleep Duration: Less than 5 hours
# Dietary Habits: Healthy
# Degree: BA
# Have you ever had suicidal thoughts ?: No
# Work/Study Hours: 9.0
# Financial Stress: 1.0
# Family History of Mental Illness: Yes
# Depression: 0

# %% [markdown]
# ![image.png](attachment:023fd383-8309-4e43-a08d-9c5acf4d7e6c.png)

# %%
from langchain_community.document_loaders import PyPDFLoader

loader_ob = PyPDFLoader(r'C:\YashAssets\PythonProjects\GenAi\GenAI_Learning\LangChain\GenAI_Applications\DataBase\GermanyInstitutionsRules.pdf')

doc = PyPDFLoader.load(loader_ob)
len(doc)

print(doc[0].page_content)
# Out:
# Studying in Germany
# A Practical Guide for
# International Students
# 7th Edition

# %% [markdown]
# ![image.png](attachment:01e46d4c-02d7-49ef-8a81-10005dd440f8.png)

# %%
from langchain_community.document_loaders import DirectoryLoader, PyPDFLoader

loader_ob = DirectoryLoader(path=r'C:\YashAssets\PythonProjects\GenAi\GenAI_Learning\LangChain\GenAI_Applications\DataBase',glob='*.pdf', loader_cls=PyPDFLoader)

docs = DirectoryLoader.lazy_load(loader_ob)
for doc in docs:
    print(doc.page_content)
# Out:
# Job
# regulations for
# international
# students
# in Germany
# Information for
# students
# English version
# Working in Germany
# A part-time job provides you with the opportunity to gain experience,
# get to know Germany, make contacts and supplement the financing
# of your studies. It is very difficult to finance your studies and life in
# Germany with a part-time job alone, and if you have a part-time job
# that takes up a lot of time, your academic performance will suffer.
# This may prolong your studies and, in the worst case, jeopardise
# your residence title.
# IMPORTANT For many student jobs, knowledge of German
# is necessary.
# Students from the EU/EEA/Switzerland
# If you are a student with citizenship in a member state of the Euro -
# pean Union (EU), the European Economic Area (EEA) or Switzerland
# you may take up any type of work in Germany under the same
# conditions as German students.
# IMPORTANT If you are a student with citizenship in the
# ...

# %% [markdown]
# ![image.png](attachment:19c8afb8-9989-463e-b048-d801df1c666c.png)

# %%
from langchain_community.document_loaders import WebBaseLoader

loader = WebBaseLoader(r'https://www.amazon.in/Samsung-Storage-Powerful-Snapdragon-Processor/dp/B0H4L5T84X/?_encoding=UTF8&pd_rd_w=1Zzzs&content-id=amzn1.sym.c7856867-7399-4487-8ea1-2895e0decba2%3Aamzn1.symc.96b8365e-3b12-433f-a173-648d41788658&pf_rd_p=c7856867-7399-4487-8ea1-2895e0decba2&pf_rd_r=2NT63VH24TVAZK7AACFE&pd_rd_wg=DTvRu&pd_rd_r=9472132e-e518-471c-96a3-5e09c0647a8b&ref_=pd_hp_d_btf_ci_mcx_mr_hp_atf_m')
doc = WebBaseLoader.load(loader)

doc[0].metadata
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.
# {'source': 'https://www.amazon.in/Samsung-Storage-Powerful-Snapdragon-Processor/dp/B0H4L5T84X/?_encoding=UTF8&pd_rd_w=1Zzzs&content-id=amzn1.sym.c7856867-7399-4487-8ea1-2895e0decba2%3Aamzn1.symc.96b8365e-3b12-433f-a173-648d41788658&pf_rd_p=c7856867-7399-4487-8ea1-2895e0decba2&pf_rd_r=2NT63VH24TVAZK7AACFE&pd_rd_wg=DTvRu&pd_rd_r=9472132e-e518-471c-96a3-5e09c0647a8b&ref_=pd_hp_d_btf_ci_mcx_mr_hp_atf_m',
#  'title': 'Samsung Galaxy M47 5G (Rogue Red, 6GB RAM, 128GB Storage)| Powerful Snapdragon Processor| Fast LPDDR5x RAM,UFS 3.1 Storage| Gorilla Glass Victus+| IP64| Super AMOLED Display| 50MP OIS| AI| Gemini Live : Amazon.in: Electronics',
#  'description': 'Samsung Galaxy M47 5G (Rogue Red, 6GB RAM, 128GB Storage)| Powerful Snapdragon Processor| Fast LPDDR5x RAM,UFS 3.1 Storage| Gorilla Glass Victus+| IP64| Super AMOLED Display| 50MP OIS| AI| Gemini Live : Amazon.in: Electronics',
# ...

# %%
full_text = doc[0].page_content.strip()
first_500_chars = full_text[:500]

print(first_500_chars)
print(f"\n[Total Length: {len(first_500_chars)} characters]")
# Out:
# --- First 500 Characters ---
# Samsung Galaxy M47 5G (Rogue Red, 6GB RAM, 128GB Storage)| Powerful Snapdragon Processor| Fast LPDDR5x RAM,UFS 3.1 Storage| Gorilla Glass Victus+| IP64| Super AMOLED Display| 50MP OIS| AI| Gemini Live : Amazon.in: Electronics
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Skip to
#
#
#
#         Main content
#
#
#
#
#         About this item
#
#
#
#
#         About this item
#
#
#
#
#         About this item
#
#
#
#
#         Buying options
#
#
#
#
#         Compare with similar items
#
#
#
#
#
#
# [Total Length: 500 characters]
